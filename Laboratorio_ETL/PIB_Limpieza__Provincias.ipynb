# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv(r'C:\\Users\\DELL\\Downloads\\Datos_PIB_Final.csv', sep= ';', encoding='latin-1')

# %%
df.head()
# Out:
#     Provincias                                 Ramas de actividad  periodo  \
# 0  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca  2021(P)
# 1  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2020
# 2  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2019
# 3  02 Albacete  B_E. Industrias extractivas, industria manufac...  2021(P)
# 4  02 Albacete  B_E. Industrias extractivas, industria manufac...     2020
#
#        Total
# 0    884.324
# 1    768.976
# 2    791.464
# 3  1.397.006
# 4  1.194.438

# %%
df = df.rename(columns={'periodo': 'Año'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provincias          1560 non-null   object
#  1   Ramas de actividad  1560 non-null   object
#  2   Año                 1560 non-null   object
#  3   Total               1560 non-null   object
# dtypes: object(4)
# memory usage: 48.9+ KB

# %%
df.shape
# Out:
# (1560, 4)

# %%
df.head()
# Out:
#     Provincias                                 Ramas de actividad      Año  \
# 0  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca  2021(P)
# 1  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2020
# 2  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2019
# 3  02 Albacete  B_E. Industrias extractivas, industria manufac...  2021(P)
# 4  02 Albacete  B_E. Industrias extractivas, industria manufac...     2020
#
#        Total
# 0    884.324
# 1    768.976
# 2    791.464
# 3  1.397.006
# 4  1.194.438

# %%
df.isna().sum()
# Out:
# Provincias            0
# Ramas de actividad    0
# Año                   0
# Total                 0
# dtype: int64

# %%
df.nunique()
# Out:
# Provincias              52
# Ramas de actividad      10
# Año                      3
# Total                 1559
# dtype: int64

# %%
df['Ramas de actividad'].unique()
# Out:
# array(['A. Agricultura, ganadería, silvicultura y pesca',
#        'B_E. Industrias extractivas, industria manufacturera, suministro de energía eléctrica, gas, vapor y aire acondicionado, suministro de agua, actividades de saneamiento, gestión de residuos y descontaminación',
#        'C. - De las cuales: Industria manufacturera', 'F. Construcción',
#        'G_J. Comercio al por mayor y al por menor, reparación de vehículos de motor y motocicletas, transporte y almacenamiento, hostelería, información y comunicaciones',
#        'K_N. Actividades financieras y de seguros, actividades inmobiliarias, actividades profesionales, científicas y técnicas, actividades administrativas y servicios auxiliares',
#        'O_U. Administración pública y defensa, seguridad social obligatoria, educación, actividades sanitarias y de servicios sociales, actividades artísticas, recreativas y de entretenimiento, reparación de artículos de uso doméstico y otros servicios',
# ...

# %%
df[df['Ramas de actividad'] == 'PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO']
# Out:
#                Provincias                            Ramas de actividad  \
# 27            02 Albacete  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 28            02 Albacete  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 29            02 Albacete  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 57    03 Alicante/Alacant  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 58    03 Alicante/Alacant  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# ...                   ...                                           ...
# 1528             51 Ceuta  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 1529             51 Ceuta  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 1557           52 Melilla  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 1558           52 Melilla  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
# 1559           52 Melilla  PRODUCTO INTERIOR BRUTO A PRECIOS DE MERCADO
#
#           Año       Total
# 27    2021(P)   8.663.814
# 28       2020   7.855.556
# ...

# %%
df[df['Provincias'] == '02 Albacete']
# Out:
#      Provincias                                 Ramas de actividad      Año  \
# 0   02 Albacete    A. Agricultura, ganadería, silvicultura y pesca  2021(P)
# 1   02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2020
# 2   02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2019
# 3   02 Albacete  B_E. Industrias extractivas, industria manufac...  2021(P)
# 4   02 Albacete  B_E. Industrias extractivas, industria manufac...     2020
# 5   02 Albacete  B_E. Industrias extractivas, industria manufac...     2019
# 6   02 Albacete        C. - De las cuales: Industria manufacturera  2021(P)
# 7   02 Albacete        C. - De las cuales: Industria manufacturera     2020
# 8   02 Albacete        C. - De las cuales: Industria manufacturera     2019
# 9   02 Albacete                                    F. Construcción  2021(P)
# 10  02 Albacete                                    F. Construcción     2020
# ...

# %%
df['Provincias'].str.split(' ')
# Out:
# 0       [02, Albacete]
# 1       [02, Albacete]
# 2       [02, Albacete]
# 3       [02, Albacete]
# 4       [02, Albacete]
#              ...
# 1555     [52, Melilla]
# 1556     [52, Melilla]
# 1557     [52, Melilla]
# 1558     [52, Melilla]
# 1559     [52, Melilla]
# Name: Provincias, Length: 1560, dtype: object

# %%
# Divide la columna 'Provincias' en dos nuevas columnas
df[['Código', 'Provincia']] = df['Provincias'].str.split(' ', n=1, expand=True)

# %%
df.head()
# Out:
#     Provincias                                 Ramas de actividad      Año  \
# 0  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca  2021(P)
# 1  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2020
# 2  02 Albacete    A. Agricultura, ganadería, silvicultura y pesca     2019
# 3  02 Albacete  B_E. Industrias extractivas, industria manufac...  2021(P)
# 4  02 Albacete  B_E. Industrias extractivas, industria manufac...     2020
#
#        Total Código Provincia
# 0    884.324     02  Albacete
# 1    768.976     02  Albacete
# 2    791.464     02  Albacete
# 3  1.397.006     02  Albacete
# 4  1.194.438     02  Albacete

# %%
df = df.drop(columns='Provincias')

# %%
df.head() # me quedo con las provincias y sus códigos
# Out:
#                                   Ramas de actividad      Año      Total  \
# 0    A. Agricultura, ganadería, silvicultura y pesca  2021(P)    884.324
# 1    A. Agricultura, ganadería, silvicultura y pesca     2020    768.976
# 2    A. Agricultura, ganadería, silvicultura y pesca     2019    791.464
# 3  B_E. Industrias extractivas, industria manufac...  2021(P)  1.397.006
# 4  B_E. Industrias extractivas, industria manufac...     2020  1.194.438
#
#   Código Provincia
# 0     02  Albacete
# 1     02  Albacete
# 2     02  Albacete
# 3     02  Albacete
# 4     02  Albacete

# %%
df['Año'] = df['Año'].str.replace('(P)', '') #limpio los años

# %%
df.head()
# Out:
#                                   Ramas de actividad   Año      Total Código  \
# 0    A. Agricultura, ganadería, silvicultura y pesca  2021    884.324     02
# 1    A. Agricultura, ganadería, silvicultura y pesca  2020    768.976     02
# 2    A. Agricultura, ganadería, silvicultura y pesca  2019    791.464     02
# 3  B_E. Industrias extractivas, industria manufac...  2021  1.397.006     02
# 4  B_E. Industrias extractivas, industria manufac...  2020  1.194.438     02
#
#   Provincia
# 0  Albacete
# 1  Albacete
# 2  Albacete
# 3  Albacete
# 4  Albacete

# %%
df[['Cod', 'Ramas de actividad']] = df['Ramas de actividad'].str.split(' ', n=1, expand=True) #divido y luego elimino esta columna de Cod

# %%
df = df.drop(columns='Cod')

# %%
df.dtypes
# Out:
# Ramas de actividad    object
# Año                   object
# Total                 object
# Código                object
# Provincia             object
# dtype: object

# %%
df['Total'] = df['Total'].str.replace('.', '').astype(int)

# %%
df['Código'] = df['Código'].astype(int)

# %%
df.dtypes
# Out:
# Ramas de actividad    object
# Año                   object
# Total                  int64
# Código                 int64
# Provincia             object
# dtype: object

# %%
df.head()
# Out:
#                                   Ramas de actividad   Año    Total  Código  \
# 0       Agricultura, ganadería, silvicultura y pesca  2021   884324       2
# 1       Agricultura, ganadería, silvicultura y pesca  2020   768976       2
# 2       Agricultura, ganadería, silvicultura y pesca  2019   791464       2
# 3  Industrias extractivas, industria manufacturer...  2021  1397006       2
# 4  Industrias extractivas, industria manufacturer...  2020  1194438       2
#
#   Provincia
# 0  Albacete
# 1  Albacete
# 2  Albacete
# 3  Albacete
# 4  Albacete

# %%
df['Año'] = df['Año'].astype(int)

# %%
df.shape
# Out:
# (1560, 5)

# %%
df = df.drop(columns='Provincia')

# %%
df.rename(columns={'Código' : 'Código Provincia'})
# Out:
#                                      Ramas de actividad   Año    Total  \
# 0          Agricultura, ganadería, silvicultura y pesca  2021   884324
# 1          Agricultura, ganadería, silvicultura y pesca  2020   768976
# 2          Agricultura, ganadería, silvicultura y pesca  2019   791464
# 3     Industrias extractivas, industria manufacturer...  2021  1397006
# 4     Industrias extractivas, industria manufacturer...  2020  1194438
# ...                                                 ...   ...      ...
# 1555                          netos sobre los productos  2020   132490
# 1556                          netos sobre los productos  2019   151213
# 1557                INTERIOR BRUTO A PRECIOS DE MERCADO  2021  1616543
# 1558                INTERIOR BRUTO A PRECIOS DE MERCADO  2020  1514009
# 1559                INTERIOR BRUTO A PRECIOS DE MERCADO  2019  1625086
#
#       Código Provincia
# 0                    2
# 1                    2
# 2                    2
# ...

# %%
df.to_csv('C:\\Users\\DELL\\Git\\Laboratorio_ETL\\datos\\datos_PIB.csv', index=False)
